# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Project6/')
# !pwd
# Out:
# /content/drive/MyDrive/Project6

# %%
# !python train_model_Bi-LSTM.py --dataset process_data/new_dataset.csv --row 250 --epochs 15 --batch_size 256
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2023-10-16 19:09:23.958174: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-16 19:09:25.762907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [INFO] loading dataset...
# [[581, 7837], [581, 7837, 7838], [581, 7837, 7838, 190], [581, 7837, 7838, 190, 179], [581, 7837, 7838, 190, 179, 4], [581, 7837, 7838, 190, 179, 4, 7839], [581, 7837, 7838, 190, 179, 4, 7839, 2918], [581, 7837, 7838, 190, 179, 4, 7839, 2918, 7840], [581, 7837, 7838, 190, 179, 4, 7839, 2918, 7840, 43], [581, 7837, 7838, 190, 179, 4, 7839, 2918, 7840, 43, 581]]
# 22418
# ...
